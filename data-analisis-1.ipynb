# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/players_22.csv', low_memory=False)

df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19234     261962  https://sofifa.com/player/261962/defu-song/220002
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                short_name                            long_name  \
# 0                L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %%
# Selecion de columnas de interes
df = df[['short_name','age','nationality_name', 'overall','potential','club_name','value_eur','wage_eur','player_positions']]

df['player_positions'] = df['player_positions'].str.split(',',expand=True)[0]

#Eliminar valores nulos
df.dropna(inplace=True)

df
# Out:
#                short_name  age     nationality_name  overall  potential  \
# 0                L. Messi   34            Argentina       93         93
# 1          R. Lewandowski   32               Poland       92         92
# 2       Cristiano Ronaldo   36             Portugal       91         91
# 3               Neymar Jr   29               Brazil       91         91
# 4            K. De Bruyne   30              Belgium       91         91
# ...                   ...  ...                  ...      ...        ...
# 19234           Song Defu   22             China PR       47         52
# 19235           C. Porter   19  Republic of Ireland       47         59
# 19236            N. Logue   21  Republic of Ireland       47         55
# 19237           L. Rudden   19  Republic of Ireland       47         60
# 19238  E. Lalchhanchhuaha   19                India       47         60
#
#                  club_name    value_eur  wage_eur player_positions
# ...

# %%
# Eliminar jugadores

players_missing_worldcup = ['K. Benzema','S. Mané','S. Agüero']

# Metodo para ayudar a encontrar elementos dentro de un columna (True o false)
Eliminar_index = df[df['short_name'].isin(players_missing_worldcup)].index

#axis = 0 hace referencia a las filas 
df.drop(Eliminar_index, axis=0, inplace=True)
# Out:
#            short_name  age nationality_name  overall  potential  \
# 0            L. Messi   34        Argentina       93         93
# 1      R. Lewandowski   32           Poland       92         92
# 2   Cristiano Ronaldo   36         Portugal       91         91
# 3           Neymar Jr   29           Brazil       91         91
# 4        K. De Bruyne   30          Belgium       91         91
# 5            J. Oblak   28         Slovenia       91         93
# 6           K. Mbappé   22           France       91         95
# 7            M. Neuer   35          Germany       90         90
# 8       M. ter Stegen   29          Germany       90         92
# 9             H. Kane   27          England       90         90
# 10           N. Kanté   30           France       90         90
# 12        T. Courtois   29          Belgium       89         91
# 13             H. Son   28   Korea Republic       89         89
# 14           Casemiro   29           Brazil       89         89
# ...

# %%
# Filtrar a los paises que iran al mundial

teams_worldcup = ['Qatar', 'Brazil', 'Belgium']
# Out:
# Empty DataFrame
# Columns: [short_name, age, nationality_name, overall, potential, club_name, value_eur, wage_eur, player_positions]
# Index: []
