# %% [markdown]
# ## Extraer data de la api de spotify

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id = 'e21c764c524c4c1db887a89e50cd07a5'
client_secret = 'ab076fd958094504974bdf617c8410bd'

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

lllit_id = "0oL7mgftYGFe5wWq0b9G4g"
naetek_id = "3Gwyr2ZQ0GexXr7V7w5dPP"

artist_ids = [lllit_id,naetek_id]

#artist_ids = ['0oL7mgftYGFe5wWq0b9G4g', '3Gwyr2ZQ0GexXr7V7w5dPP']  # Lista de IDs de artistas

data = {
    'Nombre del artista': [],
    'Nombre del album': [],
    'Nombre de singles': [],
    'URL': [],
    'URL imagen album': []
}



spotify_id = "0oL7mgftYGFe5wWq0b9G4g"

artist = sp.artist(lllit_id)   


#albums = sp.artist_albums(lllit_id, album_type='album')
#singles = sp.artist_albums(lllit_id, album_type='single')

# %%
for artist_id in artist_ids:
    
    artist = sp.artist(artist_id)
    
    albums = sp.artist_albums(artist_id, album_type='album')
    singles = sp.artist_albums(artist_id, album_type='single')

    # Agregar álbumes
    for album in albums['items']:
        album_name = album['name']
        album_image = album['images'][0]['url']
        album_tracks = sp.album_tracks(album['id'])

        for track in album_tracks['items']:
            data['Nombre del artista'].append(artist['name'])
            data['Nombre del album'].append(album_name)
            data['Nombre de singles'].append(track['name'])
            data['URL'].append(track['external_urls']['spotify'])
            data['URL imagen album'].append(album_image)
    # Agregar singles
    for single in singles['items']:
        single_name = single['name']
        single_image = single['images'][0]['url']
        single_tracks = sp.album_tracks(single['id'])
        
        for track in single_tracks['items']:
            data['Nombre del artista'].append(artist['name'])
            data['Nombre del album'].append(single_name)
            data['Nombre de singles'].append(track['name'])
            data['URL'].append(track['external_urls']['spotify'])
            data['URL imagen album'].append(single_image)

# Crear DataFrame
df = pd.DataFrame(data)
print(df)
# Out:
#     Nombre del artista     Nombre del album  \
# 0                lllit          Broken Abst
# 1                lllit          Broken Abst
# 2                lllit          Broken Abst
# 3                lllit          Broken Abst
# 4                lllit          Broken Abst
# ..                 ...                  ...
# 299            Nae:Tek  Sensual and Sensuos
# 300            Nae:Tek  Sensual and Sensuos
# 301            Nae:Tek            Satellite
# 302            Nae:Tek                  Awe
# 303            Nae:Tek         Dream Screen
#
#                         Nombre de singles  \
# 0                             Sampler Dub
# 1                               Eco Space
# 2             Sampler Dub - Autotel Remix
# 3                   Eco Space - Dib Remix
# 4             Sampler Dub - Lamebot Remix
# ..                                    ...
# 299  Sensual and Sensuos - Anderson M Rmx
# 300   Sensual and Sensuos - Operandum Rmx
# 301                             Satellite
# ...

# %%
df.to_csv("../data/data_spotify-api.csv",index=False)

# %%
pd.read_csv("../data/data_spotify-api.csv")
# Out:
#     Nombre del artista     Nombre del album  \
# 0                lllit          Broken Abst
# 1                lllit          Broken Abst
# 2                lllit          Broken Abst
# 3                lllit          Broken Abst
# 4                lllit          Broken Abst
# ..                 ...                  ...
# 299            Nae:Tek  Sensual and Sensuos
# 300            Nae:Tek  Sensual and Sensuos
# 301            Nae:Tek            Satellite
# 302            Nae:Tek                  Awe
# 303            Nae:Tek         Dream Screen
#
#                         Nombre de singles  \
# 0                             Sampler Dub
# 1                               Eco Space
# 2             Sampler Dub - Autotel Remix
# 3                   Eco Space - Dib Remix
# 4             Sampler Dub - Lamebot Remix
# ..                                    ...
# 299  Sensual and Sensuos - Anderson M Rmx
# 300   Sensual and Sensuos - Operandum Rmx
# 301                             Satellite
# ...
